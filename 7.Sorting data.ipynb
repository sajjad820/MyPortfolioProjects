# %%
student = {'first': ['alter','shirin','qiqi','ozge','hisam','chia'],
           'last':['gudu','mony','tai','bisgin','gudu','gudu'],
           'email':['alter_gudu12@gmail.com','shirinmony@gmail.com','qiqi34@yahoo.com','bisginozge@gmail.com','hismgudu@gmail.com','chiagudu@gmail.com'],
           'matri. num':['10243','50678','76545','32145','67856','76589']}

# %%
import pandas as pd

# %%
student_df= pd.DataFrame(student)
student_df
# Out:
#     first    last                   email matri. num
# 0   alter    gudu  alter_gudu12@gmail.com      10243
# 1  shirin    mony    shirinmony@gmail.com      50678
# 2    qiqi     tai        qiqi34@yahoo.com      76545
# 3    ozge  bisgin    bisginozge@gmail.com      32145
# 4   hisam    gudu      hismgudu@gmail.com      67856
# 5    chia    gudu      chiagudu@gmail.com      76589

# %%
student_df.sort_values(by= 'last', ascending= False)
# Out:
#     first    last                   email matri. num
# 2    qiqi     tai        qiqi34@yahoo.com      76545
# 1  shirin    mony    shirinmony@gmail.com      50678
# 0   alter    gudu  alter_gudu12@gmail.com      10243
# 4   hisam    gudu      hismgudu@gmail.com      67856
# 5    chia    gudu      chiagudu@gmail.com      76589
# 3    ozge  bisgin    bisginozge@gmail.com      32145

# %%
student_df.sort_values(by= ['last'] , ascending= False)
# Out:
#     first    last                   email matri. num
# 2    qiqi     tai        qiqi34@yahoo.com      76545
# 1  shirin    mony    shirinmony@gmail.com      50678
# 0   alter    gudu  alter_gudu12@gmail.com      10243
# 4   hisam    gudu      hismgudu@gmail.com      67856
# 5    chia    gudu      chiagudu@gmail.com      76589
# 3    ozge  bisgin    bisginozge@gmail.com      32145

# %%
student_df.sort_values(by= ['last','first'] , ascending= [False,True], inplace= True) #first column is in descending order and second column is in ascending order

# %%
student_df
# Out:
#     first    last                   email matri. num
# 2    qiqi     tai        qiqi34@yahoo.com      76545
# 1  shirin    mony    shirinmony@gmail.com      50678
# 0   alter    gudu  alter_gudu12@gmail.com      10243
# 5    chia    gudu      chiagudu@gmail.com      76589
# 4   hisam    gudu      hismgudu@gmail.com      67856
# 3    ozge  bisgin    bisginozge@gmail.com      32145

# %%
student_df.sort_index()
# Out:
#     first    last                   email matri. num
# 0   alter    gudu  alter_gudu12@gmail.com      10243
# 1  shirin    mony    shirinmony@gmail.com      50678
# 2    qiqi     tai        qiqi34@yahoo.com      76545
# 3    ozge  bisgin    bisginozge@gmail.com      32145
# 4   hisam    gudu      hismgudu@gmail.com      67856
# 5    chia    gudu      chiagudu@gmail.com      76589

# %%
student_df['last'].sort_values()
# Out:
# 3    bisgin
# 0      gudu
# 5      gudu
# 4      gudu
# 1      mony
# 2       tai
# Name: last, dtype: object

# %%
ds= pd.read_csv('D:\Data Analysis Project\survey_data\survey_results_public.csv', index_col='ResponseId')
schema_ds= pd.read_csv('D:\Data Analysis Project\survey_data\survey_results_schema.csv', index_col='qname')

# %%
pd.set_option('display.max_columns',80)
pd.set_option('display.max_rows',80)

# %%
ds.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                          Fully remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
# 4           Employed, full-time                          Fully remote
# 5           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# ResponseId
# 1                                                NaN
# ...

# %%
ds.sort_values(by='Country',ascending=False,inplace=True) #descending order
#OR
ds.sort_values(by='Country',ascending=False,inplace=True) #ascending order

ds['Country'].head(50)
# Out:
# ResponseId
# 46152    Zimbabwe
# 57743    Zimbabwe
# 44771    Zimbabwe
# 66478    Zimbabwe
# 56764    Zimbabwe
# 68960    Zimbabwe
# 38746    Zimbabwe
# 46049    Zimbabwe
# 46673    Zimbabwe
# 35586    Zimbabwe
# 71358    Zimbabwe
# 44536    Zimbabwe
# 31003    Zimbabwe
# 24120    Zimbabwe
# 19594    Zimbabwe
# 45312    Zimbabwe
# 30291    Zimbabwe
# 71980    Zimbabwe
# 27470    Zimbabwe
# 64032    Zimbabwe
# 52824    Zimbabwe
# 43528    Zimbabwe
# 36078    Zimbabwe
# 4719     Zimbabwe
# 42449    Zimbabwe
# 59418    Zimbabwe
# 72145    Zimbabwe
# 25845    Zimbabwe
# 30391    Zimbabwe
# 25819    Zimbabwe
# 3150       Zambia
# 33910      Zambia
# 53578      Zambia
# 68826      Zambia
# 71737      Zambia
# 52282      Zambia
# 19021      Zambia
# 54532      Zambia
# 58550      Zambia
# 32505      Zambia
# 56594      Zambia
# 34595      Zambia
# 63276      Zambia
# 17066      Zambia
# 52509      Zambia
# 28334      Zambia
# 25825      Zambia
# 27561      Zambia
# 65120      Zambia
# ...

# %%
ds[['Country', 'ConvertedCompYearly']].head(50)
# Out:
#              Country  ConvertedCompYearly
# ResponseId
# 46152       Zimbabwe                  NaN
# 57743       Zimbabwe                  NaN
# 44771       Zimbabwe                  NaN
# 66478       Zimbabwe              10000.0
# 56764       Zimbabwe                  NaN
# 68960       Zimbabwe                  NaN
# 38746       Zimbabwe                  NaN
# 46049       Zimbabwe                  NaN
# 46673       Zimbabwe                  NaN
# 35586       Zimbabwe                  NaN
# 71358       Zimbabwe                  NaN
# 44536       Zimbabwe               3600.0
# 31003       Zimbabwe               7200.0
# 24120       Zimbabwe                  NaN
# 19594       Zimbabwe                  NaN
# 45312       Zimbabwe                  NaN
# 30291       Zimbabwe              12000.0
# 71980       Zimbabwe              10800.0
# 27470       Zimbabwe                  NaN
# 64032       Zimbabwe              13200.0
# 52824       Zimbabwe                  NaN
# ...

# %%
ds.sort_values(by=['Country', 'ConvertedCompYearly'],ascending=[True, False], inplace= True)
ds[['Country', 'ConvertedCompYearly']].head(50)
# Out:
#                 Country  ConvertedCompYearly
# ResponseId
# 38513       Afghanistan             158484.0
# 43640       Afghanistan              92448.0
# 6892        Afghanistan              15600.0
# 43691       Afghanistan              13212.0
# 2449        Afghanistan              10894.0
# 6243        Afghanistan               5280.0
# 23224       Afghanistan               5280.0
# 55666       Afghanistan               2400.0
# 49274       Afghanistan               1634.0
# 42871       Afghanistan                  NaN
# 1960        Afghanistan                  NaN
# 70466       Afghanistan                  NaN
# 10234       Afghanistan                  NaN
# 15608       Afghanistan                  NaN
# 51548       Afghanistan                  NaN
# 55394       Afghanistan                  NaN
# 67667       Afghanistan                  NaN
# 55310       Afghanistan                  NaN
# 67566       Afghanistan                  NaN
# 3642        Afghanistan                  NaN
# ...

# %%
ds['ConvertedCompYearly'].nlargest(10)
# Out:
# ResponseId
# 40305    50000000.0
# 202      44790396.0
# 62027    35000000.0
# 70523    32500000.0
# 61044    28853768.0
# 62224    22500000.0
# 18923    22500000.0
# 66496    18000000.0
# 24164    15000000.0
# 1291     15000000.0
# Name: ConvertedCompYearly, dtype: float64

# %%
ds.nlargest(10,'ConvertedCompYearly')
#OR
#ds.nsmallest(10,'ConvertedCompYearly')
# Out:
#                                 MainBranch  \
# ResponseId
# 40305       I am a developer by profession
# 202         I am a developer by profession
# 62027       I am a developer by profession
# 70523       I am a developer by profession
# 61044       I am a developer by profession
# 62224       I am a developer by profession
# 18923       I am a developer by profession
# 66496       I am a developer by profession
# 24164       I am a developer by profession
# 1291        I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 40305       Independent contractor, freelancer, or self-em...
# 202                                       Employed, full-time
# 62027                                     Employed, full-time
# 70523       Independent contractor, freelancer, or self-em...
# 61044                                     I prefer not to say
# 62224                                     Employed, full-time
# ...

# %%
df1= ds.nlargest(10,'ConvertedCompYearly')
df1[['ConvertedCompYearly','Country','MainBranch','Employment','DevType']]
# Out:
#             ConvertedCompYearly  \
# ResponseId
# 40305                50000000.0
# 202                  44790396.0
# 62027                35000000.0
# 70523                32500000.0
# 61044                28853768.0
# 62224                22500000.0
# 18923                22500000.0
# 66496                18000000.0
# 24164                15000000.0
# 1291                 15000000.0
#
#                                                       Country  \
# ResponseId
# 40305       United Kingdom of Great Britain and Northern I...
# 202                                                  Portugal
# 62027                                United States of America
# 70523                                United States of America
# 61044                                                Thailand
# 62224                                United States of America
# 18923                                United States of America
# 66496                                United States of America
# ...
