# %%
import pandas as pd

# %%
d_parser= lambda x:pd.datetime.strptime(x,'%Y-%m-%d')
crypto_ds= pd.read_csv('D:\Data Analysis Project\Binance_USD.csv', parse_dates=['Date'], date_parser=d_parser)
# Out:
# <ipython-input-23-3c2e00ce8f9d>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   d_parser= lambda x:pd.datetime.strptime(x,'%Y-%m-%d')

# %%
crypto_ds.head()
# Out:
#         Date      Open      High       Low     Close     Volume Currency
# 0 2019-09-20  1.001393  1.006965  0.998945  1.001464   255936.0      USD
# 1 2019-09-21  1.001320  1.007052  1.000069  1.001984   172854.0      USD
# 2 2019-09-22  1.002346  1.007011  0.998558  1.003114   150590.0      USD
# 3 2019-09-23  1.003591  1.012758  0.999545  1.002431  1532224.0      USD
# 4 2019-09-24  1.002344  1.059820  0.994858  1.007416  4110761.0      USD

# %%
crypto_ds.shape
# Out:
# (1068, 7)

# %%
crypto_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1068 entries, 0 to 1067
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1068 non-null   datetime64[ns]
#  1   Open      1068 non-null   float64
#  2   High      1068 non-null   float64
#  3   Low       1068 non-null   float64
#  4   Close     1068 non-null   float64
#  5   Volume    1068 non-null   float64
#  6   Currency  1068 non-null   object
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 58.5+ KB

# %%
crypto_ds.loc[0,'Date'].day_name()
# Out:
# 'Friday'

# %%
crypto_ds.describe()
# Out:
#               Open         High          Low        Close        Volume
# count  1068.000000  1068.000000  1068.000000  1068.000000  1.068000e+03
# mean      1.000749     1.005022     0.997319     1.000771  3.418254e+09
# std       0.003053     0.007863     0.006115     0.003111  1.005511e+10
# min       0.970006     0.999900     0.886124     0.970006  1.384810e+05
# 25%       0.999866     1.000678     0.997786     0.999866  1.054078e+08
# 50%       1.000175     1.001939     0.998641     1.000174  3.075905e+09
# 75%       1.001142     1.006972     0.999699     1.001122  5.262161e+09
# max       1.049333     1.106512     1.007452     1.052356  3.155511e+11

# %%
crypto_ds.head()
# Out:
#          Date      Open      High       Low     Close     Volume Currency
# 0  2019-09-20  1.001393  1.006965  0.998945  1.001464   255936.0      USD
# 1  2019-09-21  1.001320  1.007052  1.000069  1.001984   172854.0      USD
# 2  2019-09-22  1.002346  1.007011  0.998558  1.003114   150590.0      USD
# 3  2019-09-23  1.003591  1.012758  0.999545  1.002431  1532224.0      USD
# 4  2019-09-24  1.002344  1.059820  0.994858  1.007416  4110761.0      USD

# %%
crypto_ds.loc[4,'Date'].day_name() #day_name function will not work because the values in'Date' column is in String format
# Out:
# 'Tuesday'

# %%
crypto_ds['Date']= pd.to_datetime(crypto_ds['Date'])
#OR 
#crypto_ds['Date']= pd.to_datetime(crypto_ds['Date'], format='%Y-%m-%d %I-%p')# it will be used when it has time as well
crypto_ds
# Out:
#            Date      Open      High       Low     Close        Volume Currency
# 0    2019-09-20  1.001393  1.006965  0.998945  1.001464  2.559360e+05      USD
# 1    2019-09-21  1.001320  1.007052  1.000069  1.001984  1.728540e+05      USD
# 2    2019-09-22  1.002346  1.007011  0.998558  1.003114  1.505900e+05      USD
# 3    2019-09-23  1.003591  1.012758  0.999545  1.002431  1.532224e+06      USD
# 4    2019-09-24  1.002344  1.059820  0.994858  1.007416  4.110761e+06      USD
# ...         ...       ...       ...       ...       ...           ...      ...
# 1063 2022-08-18  1.000106  1.000916  0.999570  1.000258  4.491890e+09      USD
# 1064 2022-08-19  1.000301  1.001314  0.998632  1.000175  7.543539e+09      USD
# 1065 2022-08-20  1.000162  1.000823  0.999860  1.000105  4.443918e+09      USD
# 1066 2022-08-21  1.000064  1.000562  0.999699  1.000075  4.140858e+09      USD
# 1067 2022-08-23  1.000098  1.000619  1.000098  1.000373  4.894390e+09      USD
#
# [1068 rows x 7 columns]

# %%
crypto_ds.loc[0,'Date'].day_name()
# Out:
# 'Friday'

# %%
crypto_ds['Date'].dt.day_name() #getting the day of all the dates
# Out:
# 0         Friday
# 1       Saturday
# 2         Sunday
# 3         Monday
# 4        Tuesday
#           ...
# 1063    Thursday
# 1064      Friday
# 1065    Saturday
# 1066      Sunday
# 1067     Tuesday
# Name: Date, Length: 1068, dtype: object

# %%
crypto_ds['NameOfDay']= crypto_ds['Date'].dt.day_name()
crypto_ds
# Out:
#            Date      Open      High       Low     Close        Volume  \
# 0    2019-09-20  1.001393  1.006965  0.998945  1.001464  2.559360e+05
# 1    2019-09-21  1.001320  1.007052  1.000069  1.001984  1.728540e+05
# 2    2019-09-22  1.002346  1.007011  0.998558  1.003114  1.505900e+05
# 3    2019-09-23  1.003591  1.012758  0.999545  1.002431  1.532224e+06
# 4    2019-09-24  1.002344  1.059820  0.994858  1.007416  4.110761e+06
# ...         ...       ...       ...       ...       ...           ...
# 1063 2022-08-18  1.000106  1.000916  0.999570  1.000258  4.491890e+09
# 1064 2022-08-19  1.000301  1.001314  0.998632  1.000175  7.543539e+09
# 1065 2022-08-20  1.000162  1.000823  0.999860  1.000105  4.443918e+09
# 1066 2022-08-21  1.000064  1.000562  0.999699  1.000075  4.140858e+09
# 1067 2022-08-23  1.000098  1.000619  1.000098  1.000373  4.894390e+09
#
#      Currency NameOfDay
# 0         USD    Friday
# 1         USD  Saturday
# 2         USD    Sunday
# 3         USD    Monday
# ...

# %%
crypto_ds['Date'].min()
# Out:
# Timestamp('2019-09-20 00:00:00')

# %%
crypto_ds['Date'].max()
# Out:
# Timestamp('2022-08-23 00:00:00')

# %%
crypto_ds['Date'].max()-crypto_ds['Date'].min()
# Out:
# Timedelta('1068 days 00:00:00')

# %%
filt= (crypto_ds['Date']<='2020')
crypto_ds.loc[filt]
# Out:
#           Date      Open      High       Low     Close     Volume Currency  \
# 0   2019-09-20  1.001393  1.006965  0.998945  1.001464   255936.0      USD
# 1   2019-09-21  1.001320  1.007052  1.000069  1.001984   172854.0      USD
# 2   2019-09-22  1.002346  1.007011  0.998558  1.003114   150590.0      USD
# 3   2019-09-23  1.003591  1.012758  0.999545  1.002431  1532224.0      USD
# 4   2019-09-24  1.002344  1.059820  0.994858  1.007416  4110761.0      USD
# ..         ...       ...       ...       ...       ...        ...      ...
# 99  2019-12-28  1.006660  1.009971  1.002121  1.002121  3228214.0      USD
# 100 2019-12-29  1.002160  1.026884  1.001347  1.004819  4262470.0      USD
# 101 2019-12-30  1.004691  1.015474  1.004441  1.009295  4002995.0      USD
# 102 2019-12-31  1.009176  1.013216  1.001779  1.003195  2980269.0      USD
# 103 2020-01-01  1.002921  1.005588  1.000974  1.003361  1695088.0      USD
#
#      NameOfDay
# 0       Friday
# 1     Saturday
# 2       Sunday
# ...

# %%
filt=(crypto_ds['Date']>='2020') & (crypto_ds['Date']<'2021')
#OR
#filt=(crypto_ds['Date']>=pd.to_datetime('2020-01-01')) & (crypto_ds['Date']<pd.to_datetime('2021-01-01'))
crypto_ds.loc[filt]
# Out:
#           Date      Open      High       Low     Close        Volume Currency  \
# 103 2020-01-01  1.002921  1.005588  1.000974  1.003361  1.695088e+06      USD
# 104 2020-01-02  1.003361  1.013116  0.999636  1.002926  4.504462e+06      USD
# 105 2020-01-03  1.005113  1.007851  0.986036  1.004717  9.269972e+06      USD
# 106 2020-01-04  1.004400  1.016440  1.001000  1.008474  5.469981e+06      USD
# 107 2020-01-05  1.008080  1.016327  1.004059  1.008208  6.417221e+06      USD
# ..         ...       ...       ...       ...       ...           ...      ...
# 464 2020-12-27  0.999600  1.001000  0.998600  1.001000  1.531007e+09      USD
# 465 2020-12-28  1.001000  1.001000  0.999500  0.999800  1.212616e+09      USD
# 466 2020-12-29  0.999900  1.000600  0.999800  1.000200  1.250163e+09      USD
# 467 2020-12-30  1.000200  1.000500  1.000000  1.000200  1.387770e+09      USD
# 468 2020-12-31  1.000200  1.000500  0.999900  1.000500  1.232197e+09      USD
#
#      NameOfDay
# 103  Wednesday
# ...

# %%
crypto_ds.loc[filt]
# Out:
#           Date      Open      High       Low     Close        Volume Currency  \
# 103 2020-01-01  1.002921  1.005588  1.000974  1.003361  1.695088e+06      USD
# 104 2020-01-02  1.003361  1.013116  0.999636  1.002926  4.504462e+06      USD
# 105 2020-01-03  1.005113  1.007851  0.986036  1.004717  9.269972e+06      USD
# 106 2020-01-04  1.004400  1.016440  1.001000  1.008474  5.469981e+06      USD
# 107 2020-01-05  1.008080  1.016327  1.004059  1.008208  6.417221e+06      USD
# ..         ...       ...       ...       ...       ...           ...      ...
# 464 2020-12-27  0.999600  1.001000  0.998600  1.001000  1.531007e+09      USD
# 465 2020-12-28  1.001000  1.001000  0.999500  0.999800  1.212616e+09      USD
# 466 2020-12-29  0.999900  1.000600  0.999800  1.000200  1.250163e+09      USD
# 467 2020-12-30  1.000200  1.000500  1.000000  1.000200  1.387770e+09      USD
# 468 2020-12-31  1.000200  1.000500  0.999900  1.000500  1.232197e+09      USD
#
#      NameOfDay
# 103  Wednesday
# ...

# %%
crypto_ds.set_index('Date', inplace= True)

# %%
crypto_ds['2020'] #it gives the same result like filter condition 
                  #it is less complex than filter option
# Out:
# <ipython-input-64-dac1ed7dad17>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   crypto_ds['2020']
#                 Open      High       Low     Close        Volume Currency  \
# Date
# 2020-01-01  1.002921  1.005588  1.000974  1.003361  1.695088e+06      USD
# 2020-01-02  1.003361  1.013116  0.999636  1.002926  4.504462e+06      USD
# 2020-01-03  1.005113  1.007851  0.986036  1.004717  9.269972e+06      USD
# 2020-01-04  1.004400  1.016440  1.001000  1.008474  5.469981e+06      USD
# 2020-01-05  1.008080  1.016327  1.004059  1.008208  6.417221e+06      USD
# ...              ...       ...       ...       ...           ...      ...
# 2020-12-27  0.999600  1.001000  0.998600  1.001000  1.531007e+09      USD
# 2020-12-28  1.001000  1.001000  0.999500  0.999800  1.212616e+09      USD
# ...

# %%
crypto_ds['2020-01':'2020-02']
# Out:
#                 Open      High       Low     Close       Volume Currency  \
# Date
# 2020-01-01  1.002921  1.005588  1.000974  1.003361    1695088.0      USD
# 2020-01-02  1.003361  1.013116  0.999636  1.002926    4504462.0      USD
# 2020-01-03  1.005113  1.007851  0.986036  1.004717    9269972.0      USD
# 2020-01-04  1.004400  1.016440  1.001000  1.008474    5469981.0      USD
# 2020-01-05  1.008080  1.016327  1.004059  1.008208    6417221.0      USD
# 2020-01-06  1.007922  1.013070  0.998216  1.001591    9634691.0      USD
# 2020-01-07  1.001591  1.010436  0.996317  1.000728   17377527.0      USD
# 2020-01-08  1.000728  1.015845  0.991430  1.005744   19895939.0      USD
# 2020-01-09  1.004431  1.010593  0.997735  1.007460   10999843.0      USD
# 2020-01-10  1.007515  1.014103  0.994549  1.000153   16874485.0      USD
# 2020-01-11  1.000153  1.008124  0.994571  1.002008   10377786.0      USD
# 2020-01-12  1.000959  1.009569  0.995418  1.002930    8552239.0      USD
# ...

# %%
crypto_ds['2021-01':'2021-02']['Close'].mean()
# Out:
# 1.000035603167647

# %%
crypto_ds['2021-01']['High'].max() #highest value of USD in January,2021
# Out:
# <ipython-input-80-bd51e2745113>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   crypto_ds['2021-01']['High'].max()
# 1.0049999952316284

# %%
highs= crypto_ds['High'].resample('Y').max() 
#highs['2020-01']

# %%
# %matplotlib inline

# %%
highs.plot()
#highs['2020-01'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
crypto_ds.resample('W').mean()
# Out:
#                 Open      High       Low     Close        Volume
# Date
# 2019-09-22  1.001686  1.007009  0.999191  1.002187  1.931267e+05
# 2019-09-29  1.004815  1.021616  0.997843  1.004967  1.292250e+06
# 2019-10-06  1.003311  1.012661  0.997883  1.004861  4.664916e+05
# 2019-10-13  1.005618  1.011775  0.996480  1.004328  1.682248e+06
# 2019-10-20  1.004256  1.010485  0.998276  1.003711  9.141439e+06
# ...              ...       ...       ...       ...           ...
# 2022-07-31  0.999993  1.001781  0.998067  0.999721  6.972919e+09
# 2022-08-07  1.000097  1.000895  0.999060  1.000139  5.275356e+09
# 2022-08-14  1.000030  1.000565  0.999407  1.000015  5.934739e+09
# 2022-08-21  1.000062  1.000742  0.999467  1.000077  5.462233e+09
# 2022-08-28  1.000098  1.000619  1.000098  1.000373  4.894390e+09
#
# [154 rows x 5 columns]

# %%
crypto_ds.resample('W').agg({'Close':'mean','High':'max','Low':'min','Volume':'sum'}) #getting the weekly summary stat
#OR
crypto_ds.resample('M').agg({'Close':'mean','High':'max','Low':'min','Volume':'sum'})#getting the monthly summary stat
#OR
crypto_ds.resample('Y').agg({'Close':'mean','High':'max','Low':'min','Volume':'sum'}) #getting the yearly summary stat
# Out:
#                Close      High       Low        Volume
# Date
# 2019-12-31  1.004659  1.059820  0.963903  7.084067e+08
# 2020-12-31  1.000651  1.106512  0.886124  9.925642e+10
# 2021-12-31  1.000194  1.026673  0.995292  1.996035e+12
# 2022-12-31  1.000146  1.024690  0.995809  1.554696e+12
