# %%
import pandas as pd

# %%
ds= pd.read_csv('D:\Data Analysis Project\survey_data\survey_results_public.csv', index_col='ResponseId')
schema_ds= pd.read_csv('D:\Data Analysis Project\survey_data\survey_results_schema.csv', index_col='qname')

# %%
pd.set_option('display.max_columns',80)
pd.set_option('display.max_rows',80)

# %%
ds.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                          Fully remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
# 4           Employed, full-time                          Fully remote
# 5           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# ResponseId
# 1                                                NaN
# ...

# %%
filt= (ds['Country']=='Bangladesh')
bangladesh_ds= ds.loc[filt]
bangladesh_ds
# Out:
#                                 MainBranch  \
# ResponseId
# 646         I am a developer by profession
# 809         I am a developer by profession
# 825            I code primarily as a hobby
# 1126           I code primarily as a hobby
# 1279        I am a developer by profession
# ...                                    ...
# 72699       I am a developer by profession
# 72703       I am a developer by profession
# 72839                I am learning to code
# 73196       I am a developer by profession
# 73245       I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 646                                       Employed, full-time
# 809                                       Employed, full-time
# 825                                        Student, full-time
# 1126        Student, full-time;Not employed, but looking f...
# 1279                                       Student, full-time
# ...

# %%
bangladesh_ds.to_csv('D:\Data Analysis Project\survey_data\survey_results_bangladesh.csv')

# %%
 bangladesh_ds.to_csv('D:\Data Analysis Project\survey_data\survey_results_bangladesh.tsv',sep='\t')

# %%
bangladesh_ds.to_excel('D:\Data Analysis Project\survey_data\survey_results_bangladesh.xlsx')

# %%
test= pd.read_excel('D:\Data Analysis Project\survey_data\survey_results_bangladesh.xlsx', index_col= 'ResponseId')
test.head()
# Out:
#                                 MainBranch  \
# ResponseId
# 646         I am a developer by profession
# 809         I am a developer by profession
# 825            I code primarily as a hobby
# 1126           I code primarily as a hobby
# 1279        I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 646                                       Employed, full-time
# 809                                       Employed, full-time
# 825                                        Student, full-time
# 1126        Student, full-time;Not employed, but looking f...
# 1279                                       Student, full-time
#
#                                       RemoteWork  \
# ResponseId
# 646                               Full in-person
# 809         Hybrid (some remote, some in-person)
# 825                                          NaN
# 1126                                         NaN
# ...

# %%
bangladesh_ds.to_json('D:\Data Analysis Project\survey_data\survey_results_bangladesh.json')
#OR
bangladesh_ds.to_json('D:\Data Analysis Project\survey_data\survey_results_bangladesh.json', orient='records',lines=True)

# %%
test= pd.read_json('D:\Data Analysis Project\survey_data\survey_results_bangladesh.json', orient='records',lines=True)
test
# Out:
#                          MainBranch  \
# 0    I am a developer by profession
# 1    I am a developer by profession
# 2       I code primarily as a hobby
# 3       I code primarily as a hobby
# 4    I am a developer by profession
# ..                              ...
# 608  I am a developer by profession
# 609  I am a developer by profession
# 610           I am learning to code
# 611  I am a developer by profession
# 612  I am a developer by profession
#
#                                             Employment  \
# 0                                  Employed, full-time
# 1                                  Employed, full-time
# 2                                   Student, full-time
# 3    Student, full-time;Not employed, but looking f...
# 4                                   Student, full-time
# ..                                                 ...
# 608  Student, full-time;Independent contractor, fre...
# 609                                 Student, full-time
# ...

# %%
pip install SQLAlchemy #if it is not installed in the environment
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Writing and Reading file in SQL format

# %%
pip install psycopg2-binary
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine= create_engine('postgresql://dbuser:dbpass@localhost:5432/sample_db')

# %%
bangladesh_ds.to_sql('sample_table',engine, if_exists='replace')

# %%
sql_ds= pd.read_sql('sample_table',engine, index_col='ResponseId')
sql_ds

# %% [markdown]
# SQL query in python

# %%
sql_ds= pd.read_sql_query('SELECT*FROM sample_table',engine, index_col='ResponseId')
