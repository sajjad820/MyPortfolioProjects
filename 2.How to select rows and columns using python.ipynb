# %% [markdown]
# Importing libraries

# %%
import pandas as pd

# %% [markdown]
# Loading dataset

# %%
ds= pd.read_csv('D:\Data Analysis Project\survey_data\survey_results_public.csv')
schema_ds= pd.read_csv('D:\Data Analysis Project\survey_data\survey_results_schema.csv')

# %% [markdown]
# Displaying all the rows and columns from entire dataset

# %%
pd.set_option('display.max_columns',80)
pd.set_option('display.max_rows',80)

# %% [markdown]
# Displaying first 5 rows information from dataset

# %%
ds.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %% [markdown]
# How many rows and columns in the data?

# %%
ds.shape
# Out:
# (73268, 79)

# %% [markdown]
# Showing up all the column names in a list

# %%
ds.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %% [markdown]
# Counting the individual element in a column

# %%
ds['EdLevel'].value_counts() 
#OR
ds['Gender'].value_counts()
# Out:
# Man                                                                                   64607
# Woman                                                                                  3399
# Prefer not to say                                                                      1172
# Non-binary, genderqueer, or gender non-conforming                                       704
# Or, in your own words:                                                                  279
# Man;Non-binary, genderqueer, or gender non-conforming                                   235
# Man;Or, in your own words:                                                              171
# Woman;Non-binary, genderqueer, or gender non-conforming                                 160
# Man;Woman;Non-binary, genderqueer, or gender non-conforming                              31
# Man;Woman                                                                                24
# ...

# %% [markdown]
# Locating the attributes of rows and columns

# %%
ds.loc[3,'Gender'] # what is the value of a 4th rows in Gender column?
# Out:
# 'Man'

# %%
ds.loc[[0,1,2,3,4,5],'Gender'] #what are the values of 1-6 rows in gender column
#OR
ds.loc[0:5,'Gender'] # 0:5 is called slicing
# Out:
# 0                       NaN
# 1                       NaN
# 2                       Man
# 3                       Man
# 4                       NaN
# 5    Or, in your own words:
# Name: Gender, dtype: object

# %%
ds.loc[0:5,'Gender':'Ethnicity'] #showing up the first six rows of the Gender to Ethnicity columns
# Out:
#                    Gender                   Trans                 Sexuality  \
# 0                     NaN                     NaN                       NaN
# 1                     NaN                     NaN                       NaN
# 2                     Man                      No                  Bisexual
# 3                     Man                      No   Straight / Heterosexual
# 4                     NaN                     NaN                       NaN
# 5  Or, in your own words:  Or, in your own words:  Prefer to self-describe:
#
#                 Ethnicity
# 0                     NaN
# 1                     NaN
# 2                   White
# 3                   White
# 4                     NaN
# 5  Or, in your own words:

# %% [markdown]
# Use of dictionaries for single value [] {}

# %%
student= {'first_name': 'alter',                  #1st element called key and 2nd element called values
          'last_name':'gudu',
          'email':'alter_gudu12@gmail.com',
          'matri. num': '10243'}

# %%
student['first_name']
# Out:
# 'alter'

# %% [markdown]
# Use of dictionaries for multiple values

# %%
student = {'first_name': ['alter','shirin','qiqi','ozge','hisam'],
           'last_name':['gudu','mony','tai','bisgin','gudu'],
           'email':['alter_gudu12@gmail.com','shirinmony@gmail.com','qiqi34@yahoo.com','bisginozge@gmail.com','hismgudu@gmail.com'],
           'matri. num':['10243','50678','76545','32145','67856']}

# %% [markdown]
# Creating dataframe from using dictionary

# %%
student_df= pd.DataFrame(student)
type(student_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Showing up a series (a dataframe is consisted of multiple series)

# %%
student_df['first_name']   #example of a series
student_df.first_name #this is another optin to show a series. However the 1st option is good to use because sometime the column name and method could be same for example student_df.count  
type(student_df['first_name'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Showing up a DataFrame

# %%
student_df[['first_name','last_name'] ] 
type(student_df[['first_name','last_name'] ] )
# Out:
# pandas.core.frame.DataFrame

# %%
student_df.columns
# Out:
# Index(['first_name', 'last_name', 'email', 'matri. num'], dtype='object')

# %%
student_df.iloc[0]
# Out:
# first_name                     alter
# last_name                       gudu
# email         alter_gudu12@gmail.com
# matri. num                     10243
# Name: 0, dtype: object

# %%
student_df.iloc[[0,2],3]  
#OR
student_df.loc[[0,2],'matri. num']
# Out:
# 0    10243
# 2    76545
# Name: matri. num, dtype: object

# %%
student_df.iloc[[0,2],[3,2]] 
#OR
student_df.loc[[0,2],['matri. num','email']]
# Out:
#   matri. num                   email
# 0      10243  alter_gudu12@gmail.com
# 2      76545        qiqi34@yahoo.com
