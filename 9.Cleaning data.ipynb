# %%
import pandas as pd
import numpy as np

# %%
student = {'first_name': ['alter','shirin','qiqi','ozge','hisam',np.nan,None,'NA'],
           'last_name':['gudu','mony','tai','bisgin','gudu',np.nan,np.nan,'Missing'],
           'email':['alter_gudu12@gmail.com','shirinmony@gmail.com','qiqi34@yahoo.com','bisginozge@gmail.com','hismgudu@gmail.com',None,np.nan,'abc@gmail.com'],
           'matri. num':['10243','50678','76545','32145','67856',None,None,'Missing'],
           'age':['33','30','29','35',None,None,np.nan,'Missing']
           }

# %%
student_ds= pd.DataFrame(student)
student_ds.replace('NA',np.nan,inplace=True)
student_ds.replace('Missing',np.nan,inplace=True)
student_ds
# Out:
#   first_name last_name                   email matri. num   age
# 0      alter      gudu  alter_gudu12@gmail.com      10243    33
# 1     shirin      mony    shirinmony@gmail.com      50678    30
# 2       qiqi       tai        qiqi34@yahoo.com      76545    29
# 3       ozge    bisgin    bisginozge@gmail.com      32145    35
# 4      hisam      gudu      hismgudu@gmail.com      67856  None
# 5        NaN       NaN                    None       None  None
# 6       None       NaN                     NaN       None   NaN
# 7        NaN       NaN           abc@gmail.com        NaN   NaN

# %%
student_ds.dropna()
# Out:
#   first_name last_name                   email matri. num age
# 0      alter      gudu  alter_gudu12@gmail.com      10243  33
# 1     shirin      mony    shirinmony@gmail.com      50678  30
# 2       qiqi       tai        qiqi34@yahoo.com      76545  29
# 3       ozge    bisgin    bisginozge@gmail.com      32145  35

# %%
student_ds.isna() #showing boolean value
# Out:
#    first_name  last_name  email  matri. num    age
# 0       False      False  False       False  False
# 1       False      False  False       False  False
# 2       False      False  False       False  False
# 3       False      False  False       False  False
# 4       False      False  False       False   True
# 5        True       True   True        True   True
# 6        True       True   True        True   True
# 7        True       True  False        True   True

# %%
student_ds.fillna('MISSING') 
#OR
student_ds.fillna(0)
# Out:
#   first_name last_name                   email matri. num age
# 0      alter      gudu  alter_gudu12@gmail.com      10243  33
# 1     shirin      mony    shirinmony@gmail.com      50678  30
# 2       qiqi       tai        qiqi34@yahoo.com      76545  29
# 3       ozge    bisgin    bisginozge@gmail.com      32145  35
# 4      hisam      gudu      hismgudu@gmail.com      67856   0
# 5          0         0                       0          0   0
# 6          0         0                       0          0   0
# 7          0         0           abc@gmail.com          0   0

# %%
student_ds.dropna(axis='index', how='all')
# Out:
#   first_name last_name                   email matri. num      age
# 0      alter      gudu  alter_gudu12@gmail.com      10243       33
# 1     shirin      mony    shirinmony@gmail.com      50678       30
# 2       qiqi       tai        qiqi34@yahoo.com      76545       29
# 3       ozge    bisgin    bisginozge@gmail.com      32145       35
# 4      hisam      gudu      hismgudu@gmail.com      67856     None
# 7         NA   Missing           abc@gmail.com    Missing  Missing

# %%
student_ds.dropna(axis='columns', how='all')
#and
student_ds.dropna(axis='columns', how='any')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6, 7]

# %%
student_ds.dropna(axis='index', how='all', subset=['last_name','email'])
# Out:
#   first_name last_name                   email matri. num      age
# 0      alter      gudu  alter_gudu12@gmail.com      10243       33
# 1     shirin      mony    shirinmony@gmail.com      50678       30
# 2       qiqi       tai        qiqi34@yahoo.com      76545       29
# 3       ozge    bisgin    bisginozge@gmail.com      32145       35
# 4      hisam      gudu      hismgudu@gmail.com      67856     None
# 7         NA   Missing           abc@gmail.com    Missing  Missing

# %%
student_ds.dtypes
# Out:
# first_name    object
# last_name     object
# email         object
# matri. num    object
# age           object
# dtype: object

# %%
type(np.nan)
# Out:
# float

# %%
 student_ds['age']= student_ds['age'].astype(float)

# %%
student_ds.dtypes
# Out:
# first_name     object
# last_name      object
# email          object
# matri. num     object
# age           float64
# dtype: object

# %%
student_ds['age'].mean()
# Out:
# 31.75

# %%
na_vals= ['NA','Missing']
ds= pd.read_csv('D:\Data Analysis Project\survey_data\survey_results_public.csv', index_col='ResponseId', na_values=na_vals)
schema_ds= pd.read_csv('D:\Data Analysis Project\survey_data\survey_results_schema.csv', index_col='Column')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-ece07e0ad609> in <module>
#       1 na_vals= ['NA','Missing']
#       2 ds= pd.read_csv('D:\Data Analysis Project\survey_data\survey_results_public.csv', index_col='ResponseId', na_values=na_vals)
# ----> 3 schema_ds= pd.read_csv('D:\Data Analysis Project\survey_data\survey_results_schema.csv', index_col='Column')
#
# ...

# %%
pd.set_option('display.max_columns',80)
pd.set_option('display.max_rows',80)

# %%
ds.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                          Fully remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
# 4           Employed, full-time                          Fully remote
# 5           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# ResponseId
# 1                                                NaN
# ...

# %%
ds.columns
# Out:
# Index(['MainBranch', 'Employment', 'RemoteWork', 'CodingActivities', 'EdLevel',
#        'LearnCode', 'LearnCodeOnline', 'LearnCodeCoursesCert', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'PurchaseInfluence', 'BuyNewTool',
#        'Country', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith',
#        'OpSysProfessional use', 'OpSysPersonal use', 'VersionControlSystem',
#        'VCInteraction', 'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
ds['YearsCodePro'].head(10)
# Out:
# ResponseId
# 1     NaN
# 2     NaN
# 3       5
# 4      17
# 5       3
# 6     NaN
# 7     NaN
# 8     NaN
# 9       6
# 10     30
# Name: YearsCodePro, dtype: object

# %%
ds['YearsCodePro']= ds['YearsCodePro'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-184ebc25300a> in <module>
# ----> 1 ds['YearsCodePro']= ds['YearsCodePro'].astype(float)
#
# c:\Users\kmsaj\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# c:\Users\kmsaj\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ...

# %%
ds['YearsCodePro'].unique() #for unique values
# Out:
# array([nan, '5', '17', '3', '6', '30', '2', '10', '15', '4', '22', '20',
#        '40', '9', '14', '21', '7', '18', '25', '8', '12', '45', '1', '19',
#        '28', '24', '11', '23', 'Less than 1 year', '32', '27', '16', '44',
#        '26', '37', '46', '13', '31', '39', '34', '38', '35', '29', '42',
#        '36', '33', '43', '41', '48', '50', 'More than 50 years', '47',
#        '49'], dtype=object)

# %%
ds['YearsCodePro'].replace('Less than 1 year',0,inplace=True)
ds['YearsCodePro'].replace('More than 50 years',51,inplace=True)

# %%
ds['YearsCodePro'].unique()
# Out:
# array([nan, '5', '17', '3', '6', '30', '2', '10', '15', '4', '22', '20',
#        '40', '9', '14', '21', '7', '18', '25', '8', '12', '45', '1', '19',
#        '28', '24', '11', '23', 0, '32', '27', '16', '44', '26', '37',
#        '46', '13', '31', '39', '34', '38', '35', '29', '42', '36', '33',
#        '43', '41', '48', '50', 51, '47', '49'], dtype=object)

# %%
ds['YearsCodePro']= ds['YearsCodePro'].astype(float)

# %%
ds['YearsCodePro'].mean()
# Out:
# 9.910269519418131

# %%
ds['YearsCodePro'].median()
# Out:
# 7.0
